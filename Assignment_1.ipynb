# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/NYC_Restaurant_Inspection_Results.csv')

# %%
df.head()
df.CUISINE_DESCRIPTION.unique()
# Out:
# array(['Chinese', 'American', 'Mexican',
#        'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#        'Korean', 'Hamburgers', 'African', 'Pizza', 'Italian', 'Bakery',
#        'Salads', 'Asian', 'Indian', 'Spanish', 'Donuts', 'Jewish/Kosher',
#        'Seafood', 'Peruvian', 'Japanese', 'Thai', 'German',
#        'Mediterranean', 'Caribbean', 'Greek', 'Irish', 'Chicken',
#        'Ice Cream, Gelato, Yogurt, Ices', 'Other', 'Continental',
#        'Bagels/Pretzels', 'Caf̩/Coffee/Tea', 'Delicatessen', 'Soups',
#        'Filipino', 'Californian', 'Juice, Smoothies, Fruit Salads',
#        'Pizza/Italian', 'Middle Eastern', 'Steak', 'Soul Food',
#        'Vietnamese/Cambodian/Malaysia', 'Sandwiches', 'French',
#        'Barbecue',
#        'Bottled beverages, including water, sodas, juices, etc.',
#        'Chilean', 'Indonesian', 'Pancakes/Waffles',
#        'Sandwiches/Salads/Mixed Buffet', 'Eastern European', 'Brazilian',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79079 entries, 0 to 79078
# Data columns (total 18 columns):
# CAMIS                    79079 non-null int64
# DBA                      79079 non-null object
# BORO                     79079 non-null object
# BUILDING                 79045 non-null object
# STREET                   79079 non-null object
# ZIPCODE                  79079 non-null int64
# PHONE                    79079 non-null object
# CUISINE_DESCRIPTION      79079 non-null object
# INSPECTION_DATE          79079 non-null object
# ACTION                   79079 non-null object
# VIOLATION_CODE           78432 non-null object
# VIOLATION_DESCRIPTION    78182 non-null object
# CRITICAL_FLAG            79079 non-null object
# SCORE                    76101 non-null float64
# GRADE                    40136 non-null object
# GRADE_DATE               37651 non-null object
# RECORD_DATE              79079 non-null object
# INSPECTION_TYPE          79079 non-null object
# ...

# %%
#df.columns
#data.groupby(['col1', 'col2'])['col3'].mean()
boro_score = df.groupby(['BORO'])['SCORE'].mean()
cuisine_score = df.groupby(['CUISINE_DESCRIPTION','BORO'])['SCORE'].mean()
cuisine_score.sort_values(ascending = False).head()
# Out:
# CUISINE_DESCRIPTION  BORO
# Creole/Cajun         BROOKLYN         59.384615
# Korean               BRONX            58.000000
# Egyptian             BROOKLYN         52.041667
# German               STATEN ISLAND    51.250000
# Soups                BROOKLYN         41.000000
# Name: SCORE, dtype: float64

# %%
df.plot()

# %%
df.groupby(['BORO']).mean()
# Out:
#                       CAMIS       ZIPCODE      SCORE
# BORO
# BRONX          4.573176e+07  10461.971990  19.028530
# BROOKLYN       4.596987e+07  11219.271691  21.087285
# MANHATTAN      4.512505e+07  10022.807867  20.626474
# QUEENS         4.590234e+07  11338.047994  20.101553
# STATEN ISLAND  4.516784e+07  10307.058843  21.590565

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1115da278>,
# ...
#       dtype=object)

# %%
df.CRITICAL_FLAG.unique()
# Out:
# array(['Critical', 'Not Critical', 'Not Applicable'], dtype=object)

# %%
plt.figure(figsize = (30,30))
plt.scatter(df.CUISINE_DESCRIPTION, df.SCORE, c = df.SCORE)

# %%
plt.figure(figsize = (30,30))
plt.scatter(df.CUISINE_DESCRIPTION, df.SCORE, c = df.SCORE)

# %%
#sns.barplot(x="day", y="total_bill", data=tips)
sns.barplot(x = "BORO", y = "SCORE", data = df)

# %%
#1.box plot of the scores by boro
sns.boxplot(x="BORO", y="SCORE", data=df)

#2. histogram of the scores for one particular cuisine type

# %%
df_japanese = df.loc[df['CUISINE_DESCRIPTION'] == 'Japanese']

# %%
sns.boxplot(x="BORO", y="SCORE", data=df_japanese)

# %%
 sns.swarmplot(x="BORO", y="SCORE", data=df_japanese)

# %%
df_japanese.plot.hist()

# %%
df_japanese['SCORE'].hist(bins = 100)

# %%
df.head()
# Out:
#       CAMIS                           DBA           BORO BUILDING  \
# 0  50061389       TACK'S CHINESE TAKE OUT  STATEN ISLAND      11C
# 1  41516263                    NO QUARTER       BROOKLYN     8015
# 2  50058069              HENRI'S BACKYARD       BROOKLYN      256
# 3  40807238  RICHMOND COUNTY COUNTRY CLUB  STATEN ISLAND     1122
# 4  41374557                 M NOODLE SHOP       BROOKLYN      549
#
#                 STREET  ZIPCODE       PHONE CUISINE_DESCRIPTION  \
# 0          HOLDEN BLVD    10314  7189839854             Chinese
# 1             5 AVENUE    11209  7187019180            American
# 2              4TH AVE    11215  9293378443            American
# 3       TODT HILL ROAD    10304  7183510600            American
# 4  METROPOLITAN AVENUE    11211  7183848008             Chinese
#
#   INSPECTION_DATE                                           ACTION  \
# 0       5/17/2017  Violations were cited in the following area(s).
# ...

# %%
df3 = df.groupby(['BORO','GRADE'])['GRADE'].count().sort_values(ascending = False)
df3
df3.plot()

# %%
df['SCORE'].hist(bins = 100)

# %%
plt.figure()
df['SCORE'].plot.hist(stacked=True, bins = 20)

# %%
plt.figure()
df_japanese['SCORE'].plot.hist(stacked=True, bins = 20)

# %%
df_bar = df.groupby(['BORO','GRADE'])['GRADE'].count().sort_values(ascending = False)
df_bar
# Out:
# BORO           GRADE
# MANHATTAN      A                 12202
# BROOKLYN       A                  7765
# QUEENS         A                  6913
# BRONX          A                  2817
# MANHATTAN      B                  1423
# STATEN ISLAND  A                  1110
# BROOKLYN       B                   894
# QUEENS         B                   889
# MANHATTAN      Z                   812
#                Not Yet Graded      811
# BROOKLYN       Not Yet Graded      741
# QUEENS         Not Yet Graded      607
# BROOKLYN       Z                   483
# QUEENS         Z                   479
# BRONX          B                   325
# MANHATTAN      C                   265
# BROOKLYN       C                   238
# BRONX          Not Yet Graded      219
# QUEENS         C                   178
# BRONX          Z                   158
# STATEN ISLAND  B                   145
# MANHATTAN      P                   120
# STATEN ISLAND  Not Yet Graded      111
# ...

# %%
sns.barplot(x = "BORO", y = "SCORE", data = df)

# %%
sns.factorplot(x="INSPECTION_DATE", y="SCORE", hue='BORO', data=df)

# %%
sns.factorplot(x="INSPECTION_DATE", y="SCORE", data=df)

# %%
df.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE_DESCRIPTION', 'INSPECTION_DATE', 'ACTION', 'VIOLATION_CODE',
#        'VIOLATION_DESCRIPTION', 'CRITICAL_FLAG', 'SCORE', 'GRADE',
#        'GRADE_DATE', 'RECORD_DATE', 'INSPECTION_TYPE'],
#       dtype='object')

# %%
#sns.lmplot(x="sepal_length", y="sepal_width", hue="species", truncate=True, size=5, data=iris)
sns.lmplot(x="ZIPCODE", y="SCORE", hue="BORO", truncate=True, size=5, data=df)

# %%
df_bar
# Out:
# BORO           GRADE
# MANHATTAN      A                 12202
# BROOKLYN       A                  7765
# QUEENS         A                  6913
# BRONX          A                  2817
# MANHATTAN      B                  1423
# STATEN ISLAND  A                  1110
# BROOKLYN       B                   894
# QUEENS         B                   889
# MANHATTAN      Z                   812
#                Not Yet Graded      811
# BROOKLYN       Not Yet Graded      741
# QUEENS         Not Yet Graded      607
# BROOKLYN       Z                   483
# QUEENS         Z                   479
# BRONX          B                   325
# MANHATTAN      C                   265
# BROOKLYN       C                   238
# BRONX          Not Yet Graded      219
# QUEENS         C                   178
# BRONX          Z                   158
# STATEN ISLAND  B                   145
# MANHATTAN      P                   120
# STATEN ISLAND  Not Yet Graded      111
# ...

# %%
sns.countplot(x="GRADE", hue="BORO", data=df_japanese)

# %%
corr = df.corr()

# %%
corr
# Out:
#             CAMIS   ZIPCODE     SCORE
# CAMIS    1.000000  0.086649  0.086918
# ZIPCODE  0.086649  1.000000  0.000111
# SCORE    0.086918  0.000111  1.000000

# %%
df
# Out:
#           CAMIS                                       DBA           BORO  \
# 0      50061389                   TACK'S CHINESE TAKE OUT  STATEN ISLAND
# 1      41516263                                NO QUARTER       BROOKLYN
# 2      50058069                          HENRI'S BACKYARD       BROOKLYN
# 3      40807238              RICHMOND COUNTY COUNTRY CLUB  STATEN ISLAND
# 4      41374557                             M NOODLE SHOP       BROOKLYN
# 5      41688137  LOWER SUITES STOLI BAR SOUTH CLUB LOUNGE       BROOKLYN
# 6      40570634                        AN BEAL BOCHT CAFE          BRONX
# 7      50017063                                  MEZQUITE         QUEENS
# 8      40743578                 EL RUMBERO BAR RESTAURANT         QUEENS
# 9      50047546                            BROOKLYN DINER       BROOKLYN
# 10     50042390                 BEST EAST STAR RESTAURANT         QUEENS
# 11     50060117                                      KBBQ      MANHATTAN
# ...

# %%
plt.hist(np.log(df['GRADE']), bins = 10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-5fa1ba1305a2> in <module>()
# ----> 1 plt.hist(np.log(df['GRADE']), bins = 10)
#
# AttributeError: 'float' object has no attribute 'log'
